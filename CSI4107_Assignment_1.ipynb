# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>CSI4107, <span
# class=GramE>Winter</span> 2021</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal align=center style='text-align:center;mso-layout-grid-align:
# none;text-autospace:none'><span lang=EN-US>Assignment 1</span></p>
#
# <p class=MsoNormal align=center style='text-align:center;mso-layout-grid-align:
# none;text-autospace:none'><span lang=EN-US>Due Friday Feb 12, 22:00</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal align=center style='text-align:center;mso-layout-grid-align:
# none;text-autospace:none'><b style='mso-bidi-font-weight:normal'><span
# lang=EN-US>Microblog information retrieval system [50 points]<o:p></o:p></span></b></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US>Note</span></b><span lang=EN-US>: <b style='mso-bidi-font-weight:
# normal'>The assignment should be done in the formed groups of students.<span
# style='mso-spacerun:yes'>  </span><o:p></o:p></b></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>You will implement
# an Information Retrieval (IR) system based for a collection of documents
# (Twitter messages), available <a href="Trec_microblog11.txt">here</a>. This is
# a mini-competition to see which group will obtain the highest evaluation
# scores.</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>The collection
# is a subset of the data used in the <a
# href="https://trec.nist.gov/data/microblog2011.html">TREC 2011 Microblog
# retrieval</a> task. Each line contains the id of the Twitter message and the
# actual message. </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>You will
# submit the results of your system on a set of 49 test queries (available <a
# href="topics_MB1-49.txt">here</a>).<span style='mso-spacerun:yes'>  </span></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>An example
# topic could be in the following format:</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>&lt;<span class=GramE>top</span>&gt;<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>&lt;<span class=SpellE><span
# class=GramE>num</span></span>&gt; Number: MB001 &lt;/<span class=SpellE>num</span>&gt;<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>&lt;<span class=GramE>title</span>&gt;
# BBC World Service staff cuts &lt;/title&gt;<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>&lt;<span class=SpellE><span
# class=GramE>querytime</span></span>&gt; Tue Feb 08 12:30:27 +0000 2011 &lt;/<span
# class=SpellE>querytime</span>&gt;<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>&lt;<span class=SpellE>querytweettime</span>&gt;
# 34952194402811904 &lt;/<span class=SpellE>querytweettime</span>&gt;<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>&lt;/top&gt;<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>Implement your
# IR system using the steps pointed below as guidelines. Alternatively, you can
# use any existing IR system available, and adapt it to accomplish the same
# steps, on the provided Twitter collection.</span></p>
#
# <p class=MsoNormal style='mso-layout-grid-align:none;text-autospace:none'><span
# lang=EN-US><o:p>&nbsp;</o:p></span></p>

# %%
#code for libraries and setting
import nltk

# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>Step1. [5
# points]<span style='mso-spacerun:yes'>  </span><b style='mso-bidi-font-weight:
# normal'>Preprocessing</b>:<span style='mso-spacerun:yes'>  </span>Implement
# preprocessing functions for tokenization and <span class=SpellE>stopword</span>
# removal. The index terms will be all the words left after filtering out
# punctuation tokens, numbers, <span class=SpellE>stopwords</span>, etc.
# Optionally, you can use the Porter stemmer to stem the index words.<span
# style='mso-spacerun:yes'>  </span></span></p>
#
# <p class=MsoNormal style='margin-left:36.0pt;text-align:justify;text-justify:
# inter-ideograph;text-indent:-18.0pt;mso-list:l0 level1 lfo2;tab-stops:list 36.0pt;
# mso-layout-grid-align:none;text-autospace:none'><![if !supportLists]><span
# lang=EN-US style='mso-fareast-font-family:"Times New Roman"'><span
# style='mso-list:Ignore'>•<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></span><![endif]><u><span lang=EN-US>Input</span></u><span
# lang=EN-US>: Documents that are read one by one from the collection</span></p>
#
# <p class=MsoNormal style='margin-left:36.0pt;text-align:justify;text-justify:
# inter-ideograph;text-indent:-18.0pt;mso-list:l0 level1 lfo2;tab-stops:list 36.0pt;
# mso-layout-grid-align:none;text-autospace:none'><![if !supportLists]><span
# lang=EN-US style='mso-fareast-font-family:"Times New Roman"'><span
# style='mso-list:Ignore'>•<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></span><![endif]><u><span lang=EN-US>Output</span></u><span
# lang=EN-US>: Tokens to be added to the index (vocabulary)</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'> </span></span></p>

# %%
resultArray = []
with open('Trec_microblog11.txt', 'r') as fp:
    line = fp.readline()
    while line:
       print(line.strip())
       line = fp.readline()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-cd527670621f> in <module>
#       1 resultArray = []
#       2 with open('Trec_microblog11.txt', 'r') as fp:
# ----> 3     line = fp.readline()
#       4     while line:
#       5        print(line.strip())
#
# c:\users\theoa\appdata\local\programs\python\python37\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 4691: character maps to <undefined>

# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>Step 2. [5
# points] <b style='mso-bidi-font-weight:normal'>Indexing</b>:<span
# style='mso-spacerun:yes'>  </span>Build an inverted index, with an entry for each
# word in the vocabulary. You can use any appropriate data structure (hash table,
# linked lists, Access database, etc.). An example of possible index is presented
# below.<span style='mso-spacerun:yes'>  </span></span></p>
#
# <p class=MsoNormal style='margin-left:36.0pt;text-align:justify;text-justify:
# inter-ideograph;text-indent:-18.0pt;mso-list:l2 level1 lfo4;tab-stops:list 36.0pt;
# mso-layout-grid-align:none;text-autospace:none'><![if !supportLists]><span
# lang=EN-US style='mso-fareast-font-family:"Times New Roman"'><span
# style='mso-list:Ignore'>•<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></span><![endif]><u><span lang=EN-US>Input</span></u><span
# lang=EN-US>: Tokens obtained from the preprocessing module</span></p>
#
# <p class=MsoNormal style='margin-left:36.0pt;text-align:justify;text-justify:
# inter-ideograph;text-indent:-18.0pt;mso-list:l2 level1 lfo4;tab-stops:list 36.0pt;
# mso-layout-grid-align:none;text-autospace:none'><![if !supportLists]><span
# lang=EN-US style='mso-fareast-font-family:"Times New Roman"'><span
# style='mso-list:Ignore'>•<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></span><![endif]><u><span lang=EN-US>Output</span></u><span
# lang=EN-US>: An inverted index for fast access </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# ![picture](http://www.site.uottawa.ca/~diana/csi4107/A1_2021/A1_2021_files/image001.gif)

# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>For weighting,
# you can use the <span class=SpellE>tf-idf</span> weighting scheme (<span
# class=SpellE>w_ij</span> = <span class=SpellE>tf_ij</span> x <span
# class=SpellE>idf_i</span>). For each query, your system will produce a ranked
# list of documents, starting with the most similar to the query and ending with
# the least similar. For the query terms, you can use a modified <span
# class=SpellE>tf-idf</span> weighting scheme <span class=SpellE>w_iq</span> =
# (0.5 + 0.5 <span class=SpellE>tf_iq</span><span class=GramE>)&#8729;</span><span
# class=SpellE>idf_i</span></span></p>

# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>Step 3. [5
# points] <b style='mso-bidi-font-weight:normal'>Retrieval and Ranking</b>:<span
# style='mso-spacerun:yes'>  </span>Use the inverted index (from step 2) to find
# the limited set of documents that contain at least one of the query words.
# Compute the similarity scores between a query and each document (using cosine
# or other method).<span style='mso-spacerun:yes'>  </span></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><u><span lang=EN-US><o:p><span
#  style='text-decoration:none'>&nbsp;</span></o:p></span></u></p>
#
# <p class=MsoNormal style='margin-left:36.0pt;text-align:justify;text-justify:
# inter-ideograph;text-indent:-18.0pt;mso-list:l1 level1 lfo6;tab-stops:list 36.0pt;
# mso-layout-grid-align:none;text-autospace:none'><![if !supportLists]><span
# lang=EN-US style='mso-fareast-font-family:"Times New Roman"'><span
# style='mso-list:Ignore'>•<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></span><![endif]><u><span lang=EN-US>Input</span></u><span
# lang=EN-US>: One query and the Inverted Index (from Step2)</span></p>
#
# <p class=MsoNormal style='margin-left:36.0pt;text-align:justify;text-justify:
# inter-ideograph;text-indent:-18.0pt;mso-list:l1 level1 lfo6;tab-stops:list 36.0pt;
# mso-layout-grid-align:none;text-autospace:none'><![if !supportLists]><span
# lang=EN-US style='mso-fareast-font-family:"Times New Roman"'><span
# style='mso-list:Ignore'>•<span style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span></span><![endif]><u><span lang=EN-US>Output</span></u><span
# lang=EN-US>: Similarity values between the query and each of the documents. Rank
# the documents in decreasing order of similarity scores.</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>

# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>Step 4. [10
# points] <b style='mso-bidi-font-weight:normal'>Results file:</b> Run your
# system on the set of test queries.<span style='mso-spacerun:yes'>
# </span>Include the output in your submission as a file named Results.<span
# style='mso-spacerun:yes'>  </span></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>The file
# should have the following TREC format. Include the top-1000 results for each
# query (the queries should be ordered in ascending order): </span></p>
#
# <p class=MsoNormal><span class=SpellE><span lang=EN-US style='font-size:11.0pt;
# font-family:"Courier New"'>top<span style='mso-font-kerning:16.0pt'>ic_id</span></span></span><span
# lang=EN-US style='font-size:11.0pt;font-family:"Courier New";mso-font-kerning:
# 16.0pt'> Q0 <span class=SpellE>docno</span> rank score tag</span><span
# lang=EN-US style='mso-font-kerning:16.0pt'><br>
# where: <span class=SpellE>topic_id</span> is the topic/query number, Q0 is an
# unused field (the literal 'Q0'), <span class=SpellE>docno</span> is the tweet
# id, rank is the rank assigned by your system to the segment (1 is the highest
# rank), score is the computed degree of match between the segment and the topic,
# and tag is a unique identifier you chose for this run (same for every topic).
# Example: <o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>MB01 Q0 3857291841983309 1
# 0.999 <span class=SpellE>myRun</span><o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>MB01 Q0 3857291841983302 2
# 0.878 <span class=SpellE>myRun</span><o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>MB01 Q0 3857291841983301 3
# 0.314 <span class=SpellE>myRun</span><o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>...<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>MB01 Q0 3857291214283390
# 1000 0.000001 <span class=SpellE>myRun</span><o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>...<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>

# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>Step 5. [10
# points] <b style='mso-bidi-font-weight:normal'>Evaluation:</b> </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>For
# evaluation, you can use the <a href="http://trec.nist.gov/trec_eval/"><span
# class=SpellE>trec_eval</span> script</a>. The main evaluation measures will be
# MAP (mean average precision) and P@10 (precision in the first 10 documents
# retrieved). Compare your results with the expected results, from the relevance
# feedback file, available <a href="Trec_microblog11-qrels.txt">here</a>, in the
# following format: </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span class=SpellE><span
# lang=EN-US style='font-size:11.0pt;font-family:"Courier New"'>Q_no</span></span><span
# lang=EN-US style='font-size:11.0pt;font-family:"Courier New"'> <span
# style='mso-tab-count:1'> </span>0<span style='mso-tab-count:1'>     </span><span
# class=SpellE>tweet_id</span><span style='mso-tab-count:2'>         </span>Relevance<o:p></o:p></span></p>
#
# <p class=MsoNormal><span class=GramE><span lang=EN-US>where</span></span><span
# lang=EN-US> </span><span class=SpellE><span lang=EN-US style='font-size:11.0pt;
# font-family:"Courier New"'>Q_no</span></span><span lang=EN-US> is the query
# number and Relevance can be 0 (not relevant) or 1 (relevant). For example:</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>1<span style='mso-tab-count:
# 1'>     </span>0<span style='mso-tab-count:1'>     </span>30986508492087297<span
# style='mso-tab-count:1'>     </span>1<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>1<span style='mso-tab-count:
# 1'>     </span>0<span style='mso-tab-count:1'>     </span>30951976883716096<span
# style='mso-tab-count:1'>     </span>0<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US
# style='font-size:11.0pt;font-family:"Courier New"'>1<span style='mso-tab-count:
# 1'>     </span>0<span style='mso-tab-count:1'>     </span>30945386776498176<span
# style='mso-tab-count:1'>     </span>0<o:p></o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US>…<o:p></o:p></span></b></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US><o:p>&nbsp;</o:p></span></b></p>

# %% [markdown]
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US>Resources</span></b><span lang=EN-US>: Here is a <a
# href="http://www.site.uottawa.ca/~diana/csi5180/StopWords">list of <span
# class=SpellE>stopwords</span></a> that you can use in Step 1 (or any other list
# you prefer). In Step1 you can use regular expressions library to help with the
# filtering. If you want to use stemming, you can use the <a
# href="http://www.tartarus.org/~martin/PorterStemmer/">Porter stemmer</a>. </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US>You can use any other resources from the Internet</span></b><span
# lang=EN-US>, as long as you explain in your report how you used them
# (compilation, installation, adaptation, etc.). </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>One resource
# you can explore is the package <a
# href="http://www.cs.utexas.edu/users/mooney/ir-course/ir.jar"><span
# class=SpellE>ir.vsr</span></a>. Some documentation on <span class=SpellE>ir.vsr</span>
# is available <a
# href="http://www.cs.utexas.edu/users/mooney/ir-course/doc/index.html">here</a>.
# </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US>Other IR
# systems are available on the Internet (<a href="http://lucene.apache.org/">Lucene</a>,
# <a href="http://terrier.org/">Terrier</a>, <a
# href="http://www.lemurproject.org/">Lemur</a>, Smart, etc.). </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US>Note</span></b><span lang=EN-US>: Feel free to add any
# optimizations or components that could improve the evaluation scores. Please
# explain them in your report. But <b style='mso-bidi-font-weight:normal'>please
# do not use neural information retrieval methods</b> (based on deep learning,
# transformers, <span class=GramE>BERT</span>-like models). We will use them in Assignment
# 2.</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US>Submission instructions</span></b><span lang=EN-US>:</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>   </span>- write a README file (plain text or Word
# format) <b style='mso-bidi-font-weight:normal'>[15 points for this report]</b>
# including:</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>         </span>* <span class=GramE>your</span> names
# and student numbers. <b style='mso-bidi-font-weight:normal'>Specify how the
# tasks were divided between the team members (if this info is not provided, the
# penalty is 10 points).<o:p></o:p></b></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>         </span>* <span class=GramE>a</span> detailed
# note about the functionality of your programs</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>         </span>* complete instructions on how to run
# them</span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>         </span>* Explain the algorithms, data
# structures, and optimizations that you used in each of the three steps. How big
# was the vocabulary? Include a sample of 100 tokens from your vocabulary.
# Include the first 10 answers to queries 3 and 20. Discuss your final results. </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>   </span>- include the file named Results with the
# results for all the 49 test queries, in the required format. </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>   </span>- make sure all your programs run correctly.
# </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>   </span>- submit your assignment, including
# programs, README file, and Results file, as a zip file through <span
# class=SpellE>BrightSpace</span>. </span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><span
# style='mso-spacerun:yes'>   </span>- don’t include the initial text collection
# or any external tools.<span style='mso-spacerun:yes'>  </span></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><span lang=EN-US><o:p>&nbsp;</o:p></span></p>
#
# <p class=MsoNormal style='text-align:justify;text-justify:inter-ideograph;
# mso-layout-grid-align:none;text-autospace:none'><b style='mso-bidi-font-weight:
# normal'><span lang=EN-US>Have fun!!!<o:p></o:p></span></b></p>
